# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import glob
import keras
import tensorflow as tf
from keras.applications import ResNet152V2, ResNet50V2
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Dense, GlobalAveragePooling2D, Flatten, Dropout, Input
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.utils import shuffle

# %% [markdown]
# Generate Data From chest_xray Folder:
# * Here we split the data in a way that we have bacteria, virus and normal images. in the proper way- some of each and not in a total randomize way
# * TODO: Need to chek why the depth of the image is 3 and not 1 as in regular cnn network

# %%
# IMG_SIZE = 150
IMG_DEPTH = 3
IMG_SIZE = 224
BATCH = 16
SEED = 42

normal_dataset = glob.glob('/content/drive/MyDrive/Deep Learning Project/chest_xray/NORMAL/*.jpeg')
pneumonia_dataset = glob.glob('/content/drive/MyDrive/Deep Learning Project/chest_xray/PNEUMONIA/*.jpeg')
virus_dataset = list(filter(lambda x: 'virus' in x, pneumonia_dataset))
bacterial_dataset = list(filter(lambda x: 'bacteria' in x, pneumonia_dataset))

# %% [markdown]
# Generate Train, Validation and Test Sets:

# %%
def split_data(dataSet, testSize, valSize):
    train, test= train_test_split(dataSet, test_size=testSize, random_state=SEED, shuffle=True)
    train, val= train_test_split(train, test_size=valSize, random_state=SEED, shuffle=True)
    return train, test, val


train_normal, test_normal, val_normal = split_data(normal_dataset, 0.15, 0.038)
train_bacterial, test_bacterial, val_bacterial = split_data(bacterial_dataset, 0.05, 0.0095)
train_virus, test_virus, val_virus = split_data(virus_dataset, 0.075, 0.019)



train = [x for x in train_normal]
train.extend([x for x in train_bacterial])
train.extend([x for x in train_virus])

test = [x for x in test_normal]
test.extend([x for x in test_bacterial])
test.extend([x for x in test_virus])

val = [x for x in val_normal]
val.extend([x for x in val_bacterial])
val.extend([x for x in val_virus])

df_train = pd.DataFrame(np.concatenate([['Normal']*(len(train_normal)) , ['Pneumonia']*(len(train_bacterial) + len(train_virus))]), columns = ['class'])
df_train['image'] = [x for x in train]

df_val = pd.DataFrame(np.concatenate([['Normal']*(len(val_normal)) , ['Pneumonia']*(len(val_bacterial) + len(val_virus))]), columns = ['class'])
df_val['image'] = [x for x in val]

df_test = pd.DataFrame(np.concatenate([['Normal']*len(test_normal) , ['Pneumonia']*(len(test_bacterial) + len(test_virus))]), columns = ['class'])
df_test['image'] = [x for x in test]

# %% [markdown]
# Perform Data Augmentation on Each Set:
# * TODO: Need to check why we are doing data augmentation on all 3 sets
#   and not just on the training set as in the regular cnn network.

# %%
# With data augmentation to prevent overfitting and handling the imbalance in dataset
# Because the dataset is small we "increase" the dataset by change of images parameters.
# In this way we increase our dataset and prevent overfitting.

train_datagen = ImageDataGenerator(rescale=1/255.,
                                  zoom_range = 0.1,
                                  #rotation_range = 0.1,
                                  width_shift_range = 0.1,
                                  height_shift_range = 0.1)

test_datagen = ImageDataGenerator(rescale=1/255.)

ds_train = train_datagen.flow_from_dataframe(df_train,
                                             #directory=train_path, #dataframe contains the full paths
                                             x_col = 'image',
                                             y_col = 'class',
                                             target_size = (IMG_SIZE, IMG_SIZE),
                                             class_mode = 'binary',
                                             batch_size = BATCH,
                                             seed = SEED)

ds_val = test_datagen.flow_from_dataframe(df_val,
                                            #directory=train_path,
                                            x_col = 'image',
                                            y_col = 'class',
                                            target_size = (IMG_SIZE, IMG_SIZE),
                                            class_mode = 'binary',
                                            batch_size = BATCH,
                                            seed = SEED)

ds_test = test_datagen.flow_from_dataframe(df_test,
                                            #directory=test_path,
                                            x_col = 'image',
                                            y_col = 'class',
                                            target_size = (IMG_SIZE, IMG_SIZE),
                                            class_mode = 'binary',
                                            batch_size = 1,
                                            shuffle = False)
# Out:
# Found 5262 validated image filenames belonging to 2 classes.
# Found 105 validated image filenames belonging to 2 classes.
# Found 489 validated image filenames belonging to 2 classes.

# %% [markdown]
# # Building CNN Network- Transfer Learning with Fine Tuning

# %% [markdown]
# Create and Freeze the Base Model and Get the Pre-Trained Model
# * This function creates a base model and freezeing all of its layers.

# %%
def create_base_model():
    # --------- create base model ----------#
    base_model = ResNet50V2(
        weights='imagenet',
        input_shape=(IMG_SIZE, IMG_SIZE, IMG_DEPTH),
        include_top=False)

    # --------- FREEZE base model ----------#
    base_model.trainable = False
    return base_model

# %% [markdown]
# Get the Pre-Trained Model
# * If you are creating many models in a loop, this global state will consume
#   an increasing amount of memory over time, and you may want to clear it.
#   Calling clear_session() releases the global state: this helps avoid clutter
#   from old models and layers, especially when memory is limited.
# * We use: keras.backend.clear_session()

# %%
def get_pre_trained_model(base_model):
    # --------- get pretrained model ----------#
    keras.backend.clear_session()

    #Input shape = [width, height, color channels]
    inputs = Input(shape=(IMG_SIZE, IMG_SIZE, IMG_DEPTH))

    x = base_model(inputs, training=False)

    # Head
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.2)(x)

    #Final Layer (Output)
    output = Dense(1, activation='sigmoid')(x)

    pre_trained_model = keras.Model(inputs=[inputs], outputs=output)

    return pre_trained_model

# %% [markdown]
# Adding Fine Tuning
# * This function un-freezes the top layers of the base model.

# %%
def add_fine_tuning(base_model):
    # Set the base_model as trainable
    base_model.trainable = True

    # Print the number of layers in the base_model
    print(f"Number of Layers In the Base Model: {len(base_model.layers)}")

    # Specify the layer index from which fine-tuning will start
    fine_tune_from = -70

    # Iterate through the layers of the base_model
    # and set them as non-trainable up to the fine_tune_from index
    for layer in base_model.layers[:fine_tune_from]:
        layer.trainable = False

# %% [markdown]
# Try Different Epochs and Learning Rates
# * Compile and Train the Model for each Epoch and Learning Rate.
#
# * Plot Graphs of the Training and Validation Accuracy and Loss vs Epochs.
#
# * It is critical to only do fine tuning after the model with frozen layers has been trained to convergence.
#   If you mix randomly-initialized trainable layers with trainable layers that hold pre-trained features,
#   the randomly-initialized layers will cause very large gradient updates during training, which will destroy your pre-trained features.
#
# * It's also critical to use a very low learning rate at this stage, because you are training a much larger model than in the first round of training, on a dataset that is typically very small. As a result, you are at risk of overfitting very quickly if you apply large weight updates. Here, you only want to readapt the pretrained weights in an incremental way.

# %%
Epochs = [10, 20, 40]
learning_rates= [0.01, 0.001, 0.0001]

opt = SGD

lr_epoch_test_acc = {}
lr_epoch_test_loss = {}
for Epoch in Epochs:
  initial_epochs = Epoch//2
  for lr in learning_rates:
    base_model = create_base_model()
    model = get_pre_trained_model(base_model)
    # Training the model with all layers frozen
    model.compile(loss='binary_crossentropy',
                optimizer = opt(learning_rate=lr), metrics='accuracy')
    # model.summary()
    history = model.fit(ds_train,
            batch_size=BATCH, epochs=initial_epochs,
            validation_data=ds_val,
            steps_per_epoch=(len(df_train)/BATCH),
            validation_steps=(len(df_val)/BATCH))
    # Evaluate the Accuracy and Loss (Before Fine Tuning)
    train_acc = history.history['accuracy']
    train_loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']

    # adding fine tuning
    add_fine_tuning(base_model)
    model.compile(loss='binary_crossentropy',
                optimizer = opt(learning_rate=lr/10), metrics='accuracy')
    history_fine = model.fit(ds_train,
                        batch_size=BATCH,
                        epochs=Epoch,
                        initial_epoch=history.epoch[-1],
                        validation_data=ds_val,
                        steps_per_epoch=(len(df_train)/BATCH),
                        validation_steps=(len(df_val)/BATCH))
    # Evaluate the Accuracy and Loss (After Fine Tuning):

    test_loss, test_accuracy = model.evaluate(ds_test, verbose=0)
    lr_epoch_tuple = (Epoch, lr)
    lr_epoch_test_acc[lr_epoch_tuple] = test_accuracy
    lr_epoch_test_loss[lr_epoch_tuple] = test_loss
    print("Test Loss:", test_loss)
    print("Test Accuracy:", test_accuracy)

    train_acc += history_fine.history['accuracy']
    val_acc += history_fine.history['val_accuracy']
    train_loss += history_fine.history['loss']
    val_loss += history_fine.history['val_loss']

    # Create a figure and subplot
    fig, axs = plt.subplots(1, 2, figsize=(14, 5))
    # Plot the training and validation accuracy
    axs[0].plot(train_acc, 'bo-', label='Training Accuracy')
    axs[0].plot(val_acc, 'ro-', label='Validation Accuracy')
    axs[0].set_title(f'Training & Validation Accuracy\n opt={opt.__name__}, lr={lr}, Epochs={Epoch}')
    # axs[0].title.set_size(10) # if title is too big, change the size here
    axs[0].legend(loc='lower right')
    axs[0].set_xlabel("Epochs")
    axs[0].set_ylabel("Accuracy")

    # Plot the training and validation loss
    axs[1].plot(train_loss, 'bo-', label='Training Loss')
    axs[1].plot(val_loss, 'ro-', label='Validation Loss')
    axs[1].set_title(f'Training & Validation Loss\n opt={opt.__name__}, lr={lr}, Epochs={Epoch}')
    # axs[1].title.set_size(10) # if title is too big, change the size here
    axs[1].legend(loc='upper right')
    axs[1].set_xlabel("Epochs")
    axs[1].set_ylabel("Loss")

    # Adjust spacing between subplots
    plt.subplots_adjust(wspace=0.2)

    plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 5s 0us/step
# Epoch 1/5
# 328/328 [==============================] - 1191s 4s/step - loss: 0.2363 - accuracy: 0.8993 - val_loss: 0.2173 - val_accuracy: 0.9143
# Epoch 2/5
# 328/328 [==============================] - 136s 415ms/step - loss: 0.1697 - accuracy: 0.9320 - val_loss: 0.2018 - val_accuracy: 0.9333
# Epoch 3/5
# 328/328 [==============================] - 136s 413ms/step - loss: 0.1594 - accuracy: 0.9422 - val_loss: 0.1843 - val_accuracy: 0.9429
# Epoch 4/5
# 328/328 [==============================] - 135s 410ms/step - loss: 0.1565 - accuracy: 0.9367 - val_loss: 0.1759 - val_accuracy: 0.9333
# Epoch 5/5
# 328/328 [==============================] - 137s 416ms/step - loss: 0.1394 - accuracy: 0.9481 - val_loss: 0.1764 - val_accuracy: 0.9429
# Number of Layers In the Base Model: 190
# Epoch 5/10
# 328/328 [==============================] - 150s 438ms/step - loss: 0.1474 - accuracy: 0.9437 - val_loss: 0.1947 - val_accuracy: 0.9333
# Epoch 6/10
# 328/328 [==============================] - 140s 426ms/step - loss: 0.1047 - accuracy: 0.9601 - val_loss: 0.1418 - val_accuracy: 0.9524
# Epoch 7/10
# 328/328 [==============================] - 141s 429ms/step - loss: 0.0929 - accuracy: 0.9664 - val_loss: 0.2126 - val_accuracy: 0.9524
# Epoch 8/10
# 328/328 [==============================] - 142s 433ms/step - loss: 0.0763 - accuracy: 0.9723 - val_loss: 0.1313 - val_accuracy: 0.9810
# Epoch 9/10
# 328/328 [==============================] - 140s 427ms/step - loss: 0.0761 - accuracy: 0.9719 - val_loss: 0.1392 - val_accuracy: 0.9810
# Epoch 10/10
# 328/328 [==============================] - 143s 435ms/step - loss: 0.0653 - accuracy: 0.9757 - val_loss: 0.1238 - val_accuracy: 0.9619
# Test Loss: 0.13443733751773834
# Test Accuracy: 0.952965259552002
# Epoch 1/5
# 328/328 [==============================] - 142s 421ms/step - loss: 0.3666 - accuracy: 0.8375 - val_loss: 0.3343 - val_accuracy: 0.8762
# Epoch 2/5
# 328/328 [==============================] - 139s 423ms/step - loss: 0.2521 - accuracy: 0.8972 - val_loss: 0.2703 - val_accuracy: 0.8857
# Epoch 3/5
# 328/328 [==============================] - 141s 428ms/step - loss: 0.2176 - accuracy: 0.9088 - val_loss: 0.2413 - val_accuracy: 0.9143
# Epoch 4/5
# 328/328 [==============================] - 140s 427ms/step - loss: 0.2089 - accuracy: 0.9151 - val_loss: 0.2320 - val_accuracy: 0.9238
# Epoch 5/5
# 328/328 [==============================] - 140s 425ms/step - loss: 0.1988 - accuracy: 0.9194 - val_loss: 0.2170 - val_accuracy: 0.9333
# Number of Layers In the Base Model: 190
# Epoch 5/10
# 328/328 [==============================] - 150s 445ms/step - loss: 0.1710 - accuracy: 0.9369 - val_loss: 0.2060 - val_accuracy: 0.9143
# Epoch 6/10
# 328/328 [==============================] - 144s 437ms/step - loss: 0.1387 - accuracy: 0.9481 - val_loss: 0.1982 - val_accuracy: 0.9333
# Epoch 7/10
# 328/328 [==============================] - 145s 441ms/step - loss: 0.1320 - accuracy: 0.9498 - val_loss: 0.2002 - val_accuracy: 0.9238
# Epoch 8/10
# 328/328 [==============================] - 145s 441ms/step - loss: 0.1219 - accuracy: 0.9561 - val_loss: 0.2005 - val_accuracy: 0.9333
# Epoch 9/10
# 328/328 [==============================] - 146s 444ms/step - loss: 0.1132 - accuracy: 0.9603 - val_loss: 0.2135 - val_accuracy: 0.9143
# Epoch 10/10
# 328/328 [==============================] - 145s 441ms/step - loss: 0.1035 - accuracy: 0.9637 - val_loss: 0.1959 - val_accuracy: 0.9333
# Test Loss: 0.16493813693523407
# Test Accuracy: 0.9345602989196777
# Epoch 1/5
# 328/328 [==============================] - 148s 437ms/step - loss: 0.5185 - accuracy: 0.7457 - val_loss: 0.6862 - val_accuracy: 0.5810
# Epoch 2/5
# 328/328 [==============================] - 142s 432ms/step - loss: 0.4242 - accuracy: 0.8052 - val_loss: 0.5951 - val_accuracy: 0.6381
# Epoch 3/5
# 328/328 [==============================] - 140s 427ms/step - loss: 0.3760 - accuracy: 0.8299 - val_loss: 0.5239 - val_accuracy: 0.7238
# Epoch 4/5
# 328/328 [==============================] - 141s 427ms/step - loss: 0.3496 - accuracy: 0.8542 - val_loss: 0.4910 - val_accuracy: 0.7524
# Epoch 5/5
# 328/328 [==============================] - 140s 426ms/step - loss: 0.3368 - accuracy: 0.8487 - val_loss: 0.4496 - val_accuracy: 0.8000
# Number of Layers In the Base Model: 190
# Epoch 5/10
# 328/328 [==============================] - 149s 440ms/step - loss: 0.2998 - accuracy: 0.8788 - val_loss: 0.3777 - val_accuracy: 0.8476
# Epoch 6/10
# 328/328 [==============================] - 144s 437ms/step - loss: 0.2784 - accuracy: 0.8852 - val_loss: 0.3338 - val_accuracy: 0.8476
# Epoch 7/10
# 328/328 [==============================] - 142s 432ms/step - loss: 0.2507 - accuracy: 0.8943 - val_loss: 0.2968 - val_accuracy: 0.8476
# Epoch 8/10
# 328/328 [==============================] - 144s 436ms/step - loss: 0.2409 - accuracy: 0.9027 - val_loss: 0.2880 - val_accuracy: 0.8476
# Epoch 9/10
# 328/328 [==============================] - 143s 435ms/step - loss: 0.2283 - accuracy: 0.9073 - val_loss: 0.2692 - val_accuracy: 0.8667
# Epoch 10/10
# 328/328 [==============================] - 144s 436ms/step - loss: 0.2125 - accuracy: 0.9137 - val_loss: 0.2449 - val_accuracy: 0.8857
# Test Loss: 0.25100231170654297
# Test Accuracy: 0.9038854837417603
# Epoch 1/10
# 328/328 [==============================] - 140s 413ms/step - loss: 0.2448 - accuracy: 0.8991 - val_loss: 0.2362 - val_accuracy: 0.9143
# Epoch 2/10
# 328/328 [==============================] - 134s 406ms/step - loss: 0.1719 - accuracy: 0.9314 - val_loss: 0.2152 - val_accuracy: 0.9143
# Epoch 3/10
# 328/328 [==============================] - 135s 411ms/step - loss: 0.1618 - accuracy: 0.9375 - val_loss: 0.1896 - val_accuracy: 0.9333
# Epoch 4/10
# 328/328 [==============================] - 132s 403ms/step - loss: 0.1442 - accuracy: 0.9477 - val_loss: 0.1901 - val_accuracy: 0.9333
# Epoch 5/10
# 328/328 [==============================] - 133s 404ms/step - loss: 0.1418 - accuracy: 0.9441 - val_loss: 0.2172 - val_accuracy: 0.9333
# Epoch 6/10
# 328/328 [==============================] - 135s 410ms/step - loss: 0.1383 - accuracy: 0.9455 - val_loss: 0.1654 - val_accuracy: 0.9524
# Epoch 7/10
# 328/328 [==============================] - 136s 412ms/step - loss: 0.1331 - accuracy: 0.9527 - val_loss: 0.1898 - val_accuracy: 0.9524
# Epoch 8/10
# 328/328 [==============================] - 134s 405ms/step - loss: 0.1317 - accuracy: 0.9542 - val_loss: 0.1759 - val_accuracy: 0.9524
# Epoch 9/10
# 328/328 [==============================] - 134s 406ms/step - loss: 0.1288 - accuracy: 0.9510 - val_loss: 0.1813 - val_accuracy: 0.9524
# Epoch 10/10
# 328/328 [==============================] - 136s 413ms/step - loss: 0.1196 - accuracy: 0.9574 - val_loss: 0.2009 - val_accuracy: 0.9524
# Number of Layers In the Base Model: 190
# Epoch 10/20
# 328/328 [==============================] - 143s 426ms/step - loss: 0.1335 - accuracy: 0.9498 - val_loss: 0.2554 - val_accuracy: 0.9333
# Epoch 11/20
# 328/328 [==============================] - 138s 419ms/step - loss: 0.0954 - accuracy: 0.9643 - val_loss: 0.1975 - val_accuracy: 0.9333
# Epoch 12/20
# 328/328 [==============================] - 136s 412ms/step - loss: 0.0838 - accuracy: 0.9683 - val_loss: 0.1357 - val_accuracy: 0.9619
# Epoch 13/20
# 328/328 [==============================] - 136s 414ms/step - loss: 0.0775 - accuracy: 0.9734 - val_loss: 0.2341 - val_accuracy: 0.9333
# Epoch 14/20
# 328/328 [==============================] - 134s 406ms/step - loss: 0.0701 - accuracy: 0.9745 - val_loss: 0.1708 - val_accuracy: 0.9524
# Epoch 15/20
# 328/328 [==============================] - 136s 413ms/step - loss: 0.0592 - accuracy: 0.9791 - val_loss: 0.1630 - val_accuracy: 0.9524
# Epoch 16/20
# 328/328 [==============================] - 134s 406ms/step - loss: 0.0552 - accuracy: 0.9789 - val_loss: 0.1363 - val_accuracy: 0.9810
# Epoch 17/20
# 328/328 [==============================] - 135s 409ms/step - loss: 0.0572 - accuracy: 0.9795 - val_loss: 0.1641 - val_accuracy: 0.9619
# Epoch 18/20
# 328/328 [==============================] - 134s 409ms/step - loss: 0.0481 - accuracy: 0.9825 - val_loss: 0.1520 - val_accuracy: 0.9524
# Epoch 19/20
# 328/328 [==============================] - 135s 412ms/step - loss: 0.0458 - accuracy: 0.9840 - val_loss: 0.1660 - val_accuracy: 0.9524
# Epoch 20/20
# 328/328 [==============================] - 134s 407ms/step - loss: 0.0473 - accuracy: 0.9833 - val_loss: 0.1167 - val_accuracy: 0.9619
# Test Loss: 0.13275225460529327
# Test Accuracy: 0.9611452221870422
# Epoch 1/10
# 328/328 [==============================] - 136s 405ms/step - loss: 0.3580 - accuracy: 0.8404 - val_loss: 0.3341 - val_accuracy: 0.8286
# Epoch 2/10
# 328/328 [==============================] - 131s 397ms/step - loss: 0.2658 - accuracy: 0.8924 - val_loss: 0.2861 - val_accuracy: 0.9048
# Epoch 3/10
# 328/328 [==============================] - 131s 398ms/step - loss: 0.2287 - accuracy: 0.9065 - val_loss: 0.2620 - val_accuracy: 0.9143
# Epoch 4/10
# 328/328 [==============================] - 131s 399ms/step - loss: 0.2146 - accuracy: 0.9143 - val_loss: 0.2290 - val_accuracy: 0.9238
# Epoch 5/10
# 328/328 [==============================] - 132s 399ms/step - loss: 0.2003 - accuracy: 0.9209 - val_loss: 0.2210 - val_accuracy: 0.9333
# Epoch 6/10
# 328/328 [==============================] - 129s 393ms/step - loss: 0.1939 - accuracy: 0.9190 - val_loss: 0.2098 - val_accuracy: 0.9333
# Epoch 7/10
# 328/328 [==============================] - 131s 398ms/step - loss: 0.1738 - accuracy: 0.9350 - val_loss: 0.2198 - val_accuracy: 0.9238
# Epoch 8/10
# 328/328 [==============================] - 132s 400ms/step - loss: 0.1792 - accuracy: 0.9323 - val_loss: 0.2096 - val_accuracy: 0.9238
# Epoch 9/10
# 328/328 [==============================] - 129s 392ms/step - loss: 0.1809 - accuracy: 0.9297 - val_loss: 0.2023 - val_accuracy: 0.9333
# Epoch 10/10
# 328/328 [==============================] - 128s 391ms/step - loss: 0.1634 - accuracy: 0.9386 - val_loss: 0.1961 - val_accuracy: 0.9429
# Number of Layers In the Base Model: 190
# Epoch 10/20
# 328/328 [==============================] - 135s 399ms/step - loss: 0.1479 - accuracy: 0.9409 - val_loss: 0.1931 - val_accuracy: 0.9333
# Epoch 11/20
# 328/328 [==============================] - 130s 395ms/step - loss: 0.1379 - accuracy: 0.9477 - val_loss: 0.2002 - val_accuracy: 0.9429
# Epoch 12/20
# 328/328 [==============================] - 129s 392ms/step - loss: 0.1207 - accuracy: 0.9529 - val_loss: 0.1938 - val_accuracy: 0.9429
# Epoch 13/20
# 328/328 [==============================] - 131s 399ms/step - loss: 0.1146 - accuracy: 0.9582 - val_loss: 0.1909 - val_accuracy: 0.9333
# Epoch 14/20
# 328/328 [==============================] - 132s 403ms/step - loss: 0.1060 - accuracy: 0.9618 - val_loss: 0.2012 - val_accuracy: 0.9238
# Epoch 15/20
# 328/328 [==============================] - 131s 400ms/step - loss: 0.1076 - accuracy: 0.9609 - val_loss: 0.2057 - val_accuracy: 0.9429
# Epoch 16/20
# 328/328 [==============================] - 132s 401ms/step - loss: 0.0939 - accuracy: 0.9664 - val_loss: 0.1919 - val_accuracy: 0.9524
# Epoch 17/20
# 328/328 [==============================] - 132s 401ms/step - loss: 0.0934 - accuracy: 0.9647 - val_loss: 0.1943 - val_accuracy: 0.9524
# Epoch 18/20
# 328/328 [==============================] - 131s 399ms/step - loss: 0.0880 - accuracy: 0.9673 - val_loss: 0.1973 - val_accuracy: 0.9524
# Epoch 19/20
# 328/328 [==============================] - 132s 401ms/step - loss: 0.0893 - accuracy: 0.9673 - val_loss: 0.1758 - val_accuracy: 0.9429
# Epoch 20/20
# 328/328 [==============================] - 133s 404ms/step - loss: 0.0788 - accuracy: 0.9717 - val_loss: 0.2100 - val_accuracy: 0.9524
# Test Loss: 0.16962477564811707
# Test Accuracy: 0.9386503100395203
# Epoch 1/10
# 328/328 [==============================] - 135s 399ms/step - loss: 0.5821 - accuracy: 0.7054 - val_loss: 0.7983 - val_accuracy: 0.5238
# Epoch 2/10
# 328/328 [==============================] - 129s 393ms/step - loss: 0.4569 - accuracy: 0.7830 - val_loss: 0.6569 - val_accuracy: 0.6000
# Epoch 3/10
# 328/328 [==============================] - 128s 389ms/step - loss: 0.3966 - accuracy: 0.8214 - val_loss: 0.5576 - val_accuracy: 0.6571
# Epoch 4/10
# 328/328 [==============================] - 129s 393ms/step - loss: 0.3651 - accuracy: 0.8358 - val_loss: 0.5190 - val_accuracy: 0.7143
# Epoch 5/10
# 328/328 [==============================] - 130s 393ms/step - loss: 0.3394 - accuracy: 0.8520 - val_loss: 0.4771 - val_accuracy: 0.7429
# Epoch 6/10
# 328/328 [==============================] - 129s 393ms/step - loss: 0.3192 - accuracy: 0.8641 - val_loss: 0.4431 - val_accuracy: 0.7905
# Epoch 7/10
# 328/328 [==============================] - 128s 390ms/step - loss: 0.3035 - accuracy: 0.8691 - val_loss: 0.4290 - val_accuracy: 0.8000
# Epoch 8/10
# 328/328 [==============================] - 128s 388ms/step - loss: 0.2935 - accuracy: 0.8759 - val_loss: 0.4129 - val_accuracy: 0.8190
# Epoch 9/10
# 328/328 [==============================] - 129s 392ms/step - loss: 0.2922 - accuracy: 0.8757 - val_loss: 0.3964 - val_accuracy: 0.8381
# Epoch 10/10
# 328/328 [==============================] - 127s 387ms/step - loss: 0.2782 - accuracy: 0.8803 - val_loss: 0.3795 - val_accuracy: 0.8286
# Number of Layers In the Base Model: 190
# 328/328 [==============================] - 137s 403ms/step - loss: 0.2627 - accuracy: 0.8890 - val_loss: 0.3375 - val_accuracy: 0.8381
# Epoch 11/20
# 328/328 [==============================] - 132s 401ms/step - loss: 0.2418 - accuracy: 0.8989 - val_loss: 0.3112 - val_accuracy: 0.8476
# Epoch 12/20
# 328/328 [==============================] - 130s 395ms/step - loss: 0.2213 - accuracy: 0.9078 - val_loss: 0.2819 - val_accuracy: 0.8571
# Epoch 13/20
# 328/328 [==============================] - 131s 400ms/step - loss: 0.2128 - accuracy: 0.9139 - val_loss: 0.2752 - val_accuracy: 0.8667
# Epoch 14/20
# 328/328 [==============================] - 132s 400ms/step - loss: 0.2012 - accuracy: 0.9204 - val_loss: 0.2751 - val_accuracy: 0.8667
# Epoch 15/20
# 197/328 [================>.............] - ETA: 52s - loss: 0.2043 - accuracy: 0.9194
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-9-9e80d136716e> in <cell line: 8>()
#      30     model.compile(loss='binary_crossentropy',
#      31                 optimizer = opt(learning_rate=lr/10), metrics='accuracy')
# ---> 32     history_fine = model.fit(ds_train,
#      33                         batch_size=BATCH,
#      34                         epochs=Epoch,
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# UnknownError: Graph execution error:
#
# 2 root error(s) found.
#   (0) UNKNOWN:  FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Deep Learning Project/chest_xray/PNEUMONIA/person1757_bacteria_4599.jpeg'
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/script_ops.py", line 267, in __call__
#     ret = func(*args)
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 642, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/from_generator_op.py", line 198, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py", line 902, in wrapped_generator
#     for data in generator_fn():
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py", line 1049, in generator_fn
#     yield x[i]
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py", line 116, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py", line 370, in _get_batches_of_transformed_samples
#     img = image_utils.load_img(
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/utils/image_utils.py", line 422, in load_img
#     with open(path, "rb") as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Deep Learning Project/chest_xray/PNEUMONIA/person1757_bacteria_4599.jpeg'
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
#   (1) CANCELLED:  Function was cancelled before it was started
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_228842]

# %% [markdown]
# Print the Loss & Accuracy Dictionaries

# %%
print(f"Test Accuracy and Loss Results with Optimizer: {opt.__name__}")
print()
print()
def print_results_dict(Accuracy, Loss):
    print("Print Accuracy Results")
    for key, val in Accuracy.items():
        epochs, lr = key
        print(f"Epochs Number = {epochs}, Learning Rate = {lr}, Accuracy = {val:.3f}")
    print()
    print()
    print("Print Loss Results")
    for key, val in Loss.items():
        epochs, lr = key
        print(f"Epochs Number = {epochs}, Learning Rate = {lr}, Loss = {val:.3f}")


print_results_dict(lr_epoch_test_acc, lr_epoch_test_loss)
