# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import keras
import tensorflow as tf
import cv2
import os
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
from keras.models import Sequential
from keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.utils import shuffle

# %% [markdown]
# Generate Data From chest_xray Folder:

# %%
labels = ['NORMAL', 'PNEUMONIA']  # NORMAL = 0 , PNEUMONIA = 1
all_classes_labels = ['NORMAL', 'BACTERIA', 'VIRUS']  # NORMAL = 0 , BACTERIA = 1, VIRUS = 2
IMG_SIZE = 150


#Concatenate all images in the different folders to three lists: normal, bacterial and virus

def get_training_data(data_dir):
    normal_data = []
    bacterial_data = []
    virus_data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                # Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
                if label == 'NORMAL':
                  class_num = all_classes_labels.index('NORMAL')
                  normal_data.append([resized_arr, class_num])
                elif label == 'PNEUMONIA':
                  if "bacteria" in str(img):
                    class_num = all_classes_labels.index('BACTERIA')
                    bacterial_data.append([resized_arr, class_num])
                  elif "virus" in str(img):
                    class_num = all_classes_labels.index('VIRUS')
                    virus_data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(normal_data), np.array(bacterial_data), np.array(virus_data)


# Includes both normal and pneumonia cases.
normal_data, bacterial_data, virus_data = get_training_data('/content/drive/MyDrive/Deep Learning Project/chest_xray/')  # list of [image, label]
# Out:
# <ipython-input-3-008a6b74dcd1>:31: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(normal_data), np.array(bacterial_data), np.array(virus_data)

# %% [markdown]
# Generate Train, Validation and Test Sets:

# %%
SEED = 42
# Separate data and labels for each class
X_normal = [data[0] for data in normal_data]
y_normal = [data[1] for data in normal_data]

X_bacterial = [data[0] for data in bacterial_data]
y_bacterial = [data[1] for data in bacterial_data]

X_virus = [data[0] for data in virus_data]
y_virus = [data[1] for data in virus_data]

# Perform train-test split for each class separately
X_normal_train, X_normal_test, y_normal_train, y_normal_test = train_test_split(X_normal, y_normal, test_size=0.15, random_state=SEED)
X_bacterial_train, X_bacterial_test, y_bacterial_train, y_bacterial_test = train_test_split(X_bacterial, y_bacterial, test_size=0.05, random_state=SEED)
X_virus_train, X_virus_test, y_virus_train, y_virus_test = train_test_split(X_virus, y_virus, test_size=0.075, random_state=SEED)

# Split the training sets into training and validation sets for each class
X_normal_train, X_normal_val, y_normal_train, y_normal_val = train_test_split(X_normal_train, y_normal_train, test_size=0.038, random_state=SEED)
X_bacterial_train, X_bacterial_val, y_bacterial_train, y_bacterial_val = train_test_split(X_bacterial_train, y_bacterial_train, test_size=0.0095, random_state=SEED)
X_virus_train, X_virus_val, y_virus_train, y_virus_val = train_test_split(X_virus_train, y_virus_train, test_size=0.019, random_state=SEED)

# Merge the data and labels for all classes
X_train = np.concatenate((X_normal_train, X_bacterial_train, X_virus_train), axis=0)
y_train = np.concatenate((y_normal_train, y_bacterial_train, y_virus_train), axis=0)
X_val = np.concatenate((X_normal_val, X_bacterial_val, X_virus_val), axis=0)
y_val = np.concatenate((y_normal_val, y_bacterial_val, y_virus_val), axis=0)
X_test = np.concatenate((X_normal_test, X_bacterial_test, X_virus_test), axis=0)
y_test = np.concatenate((y_normal_test, y_bacterial_test, y_virus_test), axis=0)

# Shuffle the training data
X_train, y_train = shuffle(X_train, y_train, random_state=SEED)

# Normalize data
X_train = X_train / 255.0
X_val = X_val / 255.0
X_test = X_test / 255.0

# Reshape data for deep learning
X_train = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
X_val = X_val.reshape(-1, IMG_SIZE, IMG_SIZE, 1)
X_test = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# Rest of the code for data augmentation and model training
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=30,
    zoom_range=0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=False)

datagen.fit(X_train)

# %% [markdown]
# Building CNN Network:

# %%
def create_model():
    kernelSize = (3,3)
    poolSize = (2,2)
    strideSize = (2,2)
    # If you are creating many models in a loop, this global state will consume
    # an increasing amount of memory over time, and you may want to clear it.
    # Calling clear_session() releases the global state: this helps avoid clutter
    # from old models and layers, especially when memory is limited.
    keras.backend.clear_session()

    model = Sequential()
    model.add(Conv2D(filters=32, kernel_size=kernelSize, padding='same',
                    activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1)))
    model.add(MaxPool2D(pool_size=poolSize,strides=strideSize))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Conv2D(filters=64, kernel_size=kernelSize, padding="same", activation="relu"))
    model.add(Conv2D(filters=64, kernel_size=kernelSize, padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=poolSize,strides=strideSize))
    model.add(BatchNormalization())

    model.add(Conv2D(filters=128, kernel_size=kernelSize, padding="same", activation="relu"))
    model.add(Conv2D(filters=128, kernel_size=kernelSize, padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=poolSize,strides=strideSize))
    model.add(BatchNormalization())

    model.add(Conv2D(filters=256, kernel_size=kernelSize, padding="same", activation="relu"))
    model.add(Conv2D(filters=256, kernel_size=kernelSize, padding="same", activation="relu"))
    model.add(MaxPool2D(pool_size=poolSize,strides=strideSize))
    model.add(BatchNormalization())
    model.add(Flatten())
    model.add(Dropout(0.2))

    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(units=3, activation='softmax'))

    return model

# %% [markdown]
# Try Different Epochs and Learning Rates
# * Compile and Train the Model for each Epoch and Learning Rate
# * Plot Graphs of the Training and Validation Accuracy and Loss vs Epochs

# %%
Epochs = [10, 20, 40]
learning_rates= [0.001, 0.0005, 0.0001]
opt = SGD

lr_epoch_test_acc = {}
lr_epoch_test_loss = {}
for Epoch in Epochs:
  for lr in learning_rates:
    model = create_model()
    model.compile(optimizer=opt(learning_rate=lr),
                loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', patience=4,
                                                verbose=1, factor=0.2, min_lr=0.00000001)

    history = model.fit(X_train, y_train,
                        batch_size=16,
                        epochs=Epoch,
                        callbacks=[learning_rate_reduction],
                        validation_data=(X_val, y_val))

    test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
    lr_epoch_tuple = (Epoch, lr)
    lr_epoch_test_acc[lr_epoch_tuple] = test_accuracy
    lr_epoch_test_loss[lr_epoch_tuple] = test_loss
    print("Test Loss:", test_loss)
    print("Test Accuracy:", test_accuracy)

    train_acc = history.history['accuracy']
    train_loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']
    epochs = range(1, len(train_acc) + 1)

    # Create a figure and subplot
    fig, axs = plt.subplots(1, 2, figsize=(14, 5))

    # Plot the training and validation accuracy
    axs[0].plot(train_acc, 'bo-', label='Training Accuracy')
    axs[0].plot(val_acc, 'ro-', label='Validation Accuracy')
    axs[0].set_title(f'Training & Validation Accuracy\n opt={opt.__name__}, lr={lr}, Epochs={Epoch}')
    # axs[0].title.set_size(10) # if title is too big, change the size here
    axs[0].legend(loc='lower right')
    axs[0].set_xlabel("Epochs")
    axs[0].set_ylabel("Accuracy")

    # Plot the training and validation loss
    axs[1].plot(train_loss, 'bo-', label='Training Loss')
    axs[1].plot(val_loss, 'ro-', label='Validation Loss')
    axs[1].set_title(f'Training & Validation Loss\n opt={opt.__name__}, lr={lr}, Epochs={Epoch}')
    # axs[1].title.set_size(10) # if title is too big, change the size here
    axs[1].legend(loc='upper right')
    axs[1].set_xlabel("Epochs")
    axs[1].set_ylabel("Loss")

    # Adjust spacing between subplots
    plt.subplots_adjust(wspace=0.2)

plt.show()
# Out:
# Epoch 1/10
# 329/329 [==============================] - 23s 39ms/step - loss: 0.6277 - accuracy: 0.7351 - val_loss: 2.6668 - val_accuracy: 0.2476 - lr: 0.0010
# Epoch 2/10
# 329/329 [==============================] - 11s 34ms/step - loss: 0.5318 - accuracy: 0.7725 - val_loss: 0.6376 - val_accuracy: 0.7143 - lr: 0.0010
# Epoch 3/10
# 329/329 [==============================] - 11s 34ms/step - loss: 0.4818 - accuracy: 0.7982 - val_loss: 0.5242 - val_accuracy: 0.8095 - lr: 0.0010
# Epoch 4/10
# 329/329 [==============================] - 12s 35ms/step - loss: 0.4571 - accuracy: 0.7997 - val_loss: 0.8624 - val_accuracy: 0.6857 - lr: 0.0010
# Epoch 5/10
# 329/329 [==============================] - 12s 35ms/step - loss: 0.4291 - accuracy: 0.8183 - val_loss: 0.6349 - val_accuracy: 0.7619 - lr: 0.0010
# Epoch 6/10
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4078 - accuracy: 0.8238 - val_loss: 0.5461 - val_accuracy: 0.8000 - lr: 0.0010
# Epoch 7/10
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3899 - accuracy: 0.8339 - val_loss: 0.5045 - val_accuracy: 0.8286 - lr: 0.0010
# Epoch 8/10
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3661 - accuracy: 0.8409 - val_loss: 0.4868 - val_accuracy: 0.8286 - lr: 0.0010
# Epoch 9/10
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3515 - accuracy: 0.8521 - val_loss: 0.5275 - val_accuracy: 0.7905 - lr: 0.0010
# Epoch 10/10
# 329/329 [==============================] - 12s 36ms/step - loss: 0.
# Epoch 7/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4260 - accuracy: 0.8189 - val_loss: 0.5606 - val_accuracy: 0.8095 - lr: 5.0000e-04
# Epoch 8/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4095 - accuracy: 0.8254 - val_loss: 0.6150 - val_accuracy: 0.7619 - lr: 5.0000e-04
# Epoch 9/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4006 - accuracy: 0.8297 - val_loss: 0.5042 - val_accuracy: 0.8190 - lr: 5.0000e-04
# Epoch 10/20
# 329/329 [==============================] - ETA: 0s - loss: 0.3825 - accuracy: 0.8339
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3825 - accuracy: 0.8339 - val_loss: 0.5292 - val_accuracy: 0.8000 - lr: 5.0000e-04
# Epoch 11/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3618 - accuracy: 0.8493 - val_loss: 0.5164 - val_accuracy: 0.8095 - lr: 1.0000e-04
# Epoch 12/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3565 - accuracy: 0.8483 - val_loss: 0.4984 - val_accuracy: 0.8286 - lr: 1.0000e-04
# Epoch 13/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3467 - accuracy: 0.8540 - val_loss: 0.5139 - val_accuracy: 0.8095 - lr: 1.0000e-04
# Epoch 14/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3465 - accuracy: 0.8540 - val_loss: 0.4715 - val_accuracy: 0.8190 - lr: 1.0000e-04
# Epoch 15/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3447 - accuracy: 0.8584 - val_loss: 0.5082 - val_accuracy: 0.8190 - lr: 1.0000e-04
# Epoch 16/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3395 - accuracy: 0.8634 - val_loss: 0.5066 - val_accuracy: 0.8000 - lr: 1.0000e-04
# Epoch 17/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3361 - accuracy: 0.8607 - val_loss: 0.4949 - val_accuracy: 0.8286 - lr: 1.0000e-04
# Epoch 18/20
# 329/329 [==============================] - ETA: 0s - loss: 0.3362 - accuracy: 0.8626
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3362 - accuracy: 0.8626 - val_loss: 0.5064 - val_accuracy: 0.8190 - lr: 1.0000e-04
# Epoch 19/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3300 - accuracy: 0.8609 - val_loss: 0.4912 - val_accuracy: 0.8286 - lr: 2.0000e-05
# Epoch 20/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.3319 - accuracy: 0.8592 - val_loss: 0.4911 - val_accuracy: 0.8286 - lr: 2.0000e-05
# Test Loss: 0.46722209453582764
# Test Accuracy: 0.8159509301185608
# Epoch 1/20
# 329/329 [==============================] - 13s 36ms/step - loss: 0.8575 - accuracy: 0.6231 - val_loss: 2.0048 - val_accuracy: 0.2476 - lr: 1.0000e-04
# Epoch 2/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.6625 - accuracy: 0.7218 - val_loss: 1.5296 - val_accuracy: 0.2571 - lr: 1.0000e-04
# Epoch 3/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.6075 - accuracy: 0.7528 - val_loss: 0.9614 - val_accuracy: 0.6190 - lr: 1.0000e-04
# Epoch 4/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5794 - accuracy: 0.7577 - val_loss: 0.9225 - val_accuracy: 0.6286 - lr: 1.0000e-04
# Epoch 5/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5598 - accuracy: 0.7676 - val_loss: 0.8115 - val_accuracy: 0.6667 - lr: 1.0000e-04
# Epoch 6/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5408 - accuracy: 0.7731 - val_loss: 0.8698 - val_accuracy: 0.6762 - lr: 1.0000e-04
# Epoch 7/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5268 - accuracy: 0.7788 - val_loss: 0.7843 - val_accuracy: 0.6952 - lr: 1.0000e-04
# Epoch 8/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5079 - accuracy: 0.7864 - val_loss: 0.8057 - val_accuracy: 0.7143 - lr: 1.0000e-04
# Epoch 9/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5116 - accuracy: 0.7803 - val_loss: 0.7278 - val_accuracy: 0.7238 - lr: 1.0000e-04
# Epoch 10/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4878 - accuracy: 0.7875 - val_loss: 0.7562 - val_accuracy: 0.7238 - lr: 1.0000e-04
# Epoch 11/20
# 329/329 [==============================] - 12s 36ms/step - loss: 0.
40
# 329/329 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9246
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 329/329 [==============================] - 12s 36ms/step - loss: 0.1953 - accuracy: 0.9246 - val_loss: 0.4162 - val_accuracy: 0.8476 - lr: 5.0000e-04
# Epoch 30/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.1728 - accuracy: 0.9373 - val_loss: 0.4171 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 31/40
# 329/329 [==============================] - 12s 37ms/step - loss: 0.1745 - accuracy: 0.9411 - val_loss: 0.4121 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 32/40
# 329/329 [==============================] - 12s 37ms/step - loss: 0.1724 - accuracy: 0.9430 - val_loss: 0.4290 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 33/40
# 329/329 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 0.9437
# Epoch 33: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
# 329/329 [==============================] - 12s 36ms/step - loss: 0.1660 - accuracy: 0.9437 - val_loss: 0.4233 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 34/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.1666 - accuracy: 0.9439 - val_loss: 0.4285 - val_accuracy: 0.8571 - lr: 2.0000e-05
# Epoch 35/40
# 329/329 [==============================] - 12s 37ms/step - loss: 0.1639 - accuracy: 0.9418 - val_loss: 0.4300 - val_accuracy: 0.8571 - lr: 2.0000e-05
# Epoch 36/40
# 329/329 [==============================] - 12s 37ms/step - loss: 0.1585 - accuracy: 0.9474 - val_loss: 0.4273 - val_accuracy: 0.8571 - lr: 2.0000e-05
# Epoch 37/40
# 329/329 [==============================] - ETA: 0s - loss: 0.1653 - accuracy: 0.9407
# Epoch 37: ReduceLROnPlateau reducing learning rate to 4.000000262749381e-06.
# 329/329 [==============================] - 12s 36ms/step - loss: 0.1653 - accuracy: 0.9407 - val_loss: 0.4260 - val_accuracy: 0.8571 - lr: 2.0000e-05
# Epoch 38/40
# 329/329 [==============================] - 12s 37ms/step - loss: 0.1625 - accuracy: 0.9445 - val_loss: 0.4264 - val_accuracy: 0.8571 - lr: 4.0000e-06
# Epoch 39/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.1588 - accuracy: 0.9474 - val_loss: 0.4287 - val_accuracy: 0.8571 - lr: 4.0000e-06
# Epoch 40/40
# 329/329 [==============================] - 12s 37ms/step - loss: 0.1589 - accuracy: 0.9472 - val_loss: 0.4306 - val_accuracy: 0.8571 - lr: 4.0000e-06
# Test Loss: 0.48881641030311584
# Test Accuracy: 0.8179959058761597
# Epoch 1/40
# 329/329 [==============================] - 13s 37ms/step - loss: 0.8448 - accuracy: 0.6127 - val_loss: 2.0860 - val_accuracy: 0.2476 - lr: 1.0000e-04
# Epoch 2/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.6600 - accuracy: 0.7102 - val_loss: 1.6904 - val_accuracy: 0.2762 - lr: 1.0000e-04
# Epoch 3/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5954 - accuracy: 0.7480 - val_loss: 1.1816 - val_accuracy: 0.4857 - lr: 1.0000e-04
# Epoch 4/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5717 - accuracy: 0.7529 - val_loss: 0.8681 - val_accuracy: 0.6286 - lr: 1.0000e-04
# Epoch 5/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5466 - accuracy: 0.7695 - val_loss: 0.9597 - val_accuracy: 0.5619 - lr: 1.0000e-04
# Epoch 6/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5321 - accuracy: 0.7775 - val_loss: 0.8423 - val_accuracy: 0.6571 - lr: 1.0000e-04
# Epoch 7/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5257 - accuracy: 0.7786 - val_loss: 0.8127 - val_accuracy: 0.6476 - lr: 1.0000e-04
# Epoch 8/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5127 - accuracy: 0.7843 - val_loss: 0.8308 - val_accuracy: 0.6762 - lr: 1.0000e-04
# Epoch 9/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.5076 - accuracy: 0.7892 - val_loss: 0.8647 - val_accuracy: 0.6571 - lr: 1.0000e-04
# Epoch 10/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4918 - accuracy: 0.7892 - val_loss: 0.7990 - val_accuracy: 0.7048 - lr: 1.0000e-04
# Epoch 11/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4957 - accuracy: 0.7911 - val_loss: 0.7373 - val_accuracy: 0.7333 - lr: 1.0000e-04
# Epoch 12/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4833 - accuracy: 0.7963 - val_loss: 0.7051 - val_accuracy: 0.7429 - lr: 1.0000e-04
# Epoch 13/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4657 - accuracy: 0.7999 - val_loss: 0.7104 - val_accuracy: 0.7143 - lr: 1.0000e-04
# Epoch 14/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4688 - accuracy: 0.7995 - val_loss: 0.7453 - val_accuracy: 0.7143 - lr: 1.0000e-04
# Epoch 15/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4562 - accuracy: 0.8037 - val_loss: 0.6852 - val_accuracy: 0.7619 - lr: 1.0000e-04
# Epoch 16/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4574 - accuracy: 0.8056 - val_loss: 0.6345 - val_accuracy: 0.7619 - lr: 1.0000e-04
# Epoch 17/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4477 - accuracy: 0.8086 - val_loss: 0.6745 - val_accuracy: 0.7524 - lr: 1.0000e-04
# Epoch 18/40
# 329/329 [==============================] - 13s 38ms/step - loss: 0.4412 - accuracy: 0.8136 - val_loss: 0.6651 - val_accuracy: 0.7524 - lr: 1.0000e-04
# Epoch 19/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4364 - accuracy: 0.8115 - val_loss: 0.6458 - val_accuracy: 0.7524 - lr: 1.0000e-04
# Epoch 20/40
# 329/329 [==============================] - ETA: 0s - loss: 0.4359 - accuracy: 0.8138
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4359 - accuracy: 0.8138 - val_loss: 0.6761 - val_accuracy: 0.7429 - lr: 1.0000e-04
# Epoch 21/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4392 - accuracy: 0.8117 - val_loss: 0.6619 - val_accuracy: 0.7524 - lr: 2.0000e-05
# Epoch 22/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4330 - accuracy: 0.8170 - val_loss: 0.6676 - val_accuracy: 0.7429 - lr: 2.0000e-05
# Epoch 23/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4284 - accuracy: 0.8170 - val_loss: 0.6349 - val_accuracy: 0.7524 - lr: 2.0000e-05
# Epoch 24/40
# 329/329 [==============================] - ETA: 0s - loss: 0.4287 - accuracy: 0.8179
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 329/329 [==============================] - 12s 37ms/step - loss: 0.4287 - accuracy: 0.8179 - val_loss: 0.6481 - val_accuracy: 0.7619 - lr: 2.0000e-05
# Epoch 25/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4251 - accuracy: 0.8193 - val_loss: 0.6451 - val_accuracy: 0.7524 - lr: 4.0000e-06
# Epoch 26/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4329 - accuracy: 0.8158 - val_loss: 0.6462 - val_accuracy: 0.7524 - lr: 4.0000e-06
# Epoch 27/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4337 - accuracy: 0.8149 - val_loss: 0.6464 - val_accuracy: 0.7524 - lr: 4.0000e-06
# Epoch 28/40
# 329/329 [==============================] - ETA: 0s - loss: 0.4269 - accuracy: 0.8117
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4269 - accuracy: 0.8117 - val_loss: 0.6501 - val_accuracy: 0.7619 - lr: 4.0000e-06
# Epoch 29/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4238 - accuracy: 0.8172 - val_loss: 0.6533 - val_accuracy: 0.7619 - lr: 8.0000e-07
# Epoch 30/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4231 - accuracy: 0.8248 - val_loss: 0.6477 - val_accuracy: 0.7619 - lr: 8.0000e-07
# Epoch 31/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4199 - accuracy: 0.8216 - val_loss: 0.6524 - val_accuracy: 0.7619 - lr: 8.0000e-07
# Epoch 32/40
# 329/329 [==============================] - ETA: 0s - loss: 0.4306 - accuracy: 0.8134
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4306 - accuracy: 0.8134 - val_loss: 0.6507 - val_accuracy: 0.7524 - lr: 8.0000e-07
# Epoch 33/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4288 - accuracy: 0.8149 - val_loss: 0.6453 - val_accuracy: 0.7524 - lr: 1.6000e-07
# Epoch 34/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4265 - accuracy: 0.8174 - val_loss: 0.6495 - val_accuracy: 0.7524 - lr: 1.6000e-07
# Epoch 35/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4239 - accuracy: 0.8195 - val_loss: 0.6500 - val_accuracy: 0.7619 - lr: 1.6000e-07
# Epoch 36/40
# 329/329 [==============================] - ETA: 0s - loss: 0.4322 - accuracy: 0.8147
# Epoch 36: ReduceLROnPlateau reducing learning rate to 3.199999980552093e-08.
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4322 - accuracy: 0.8147 - val_loss: 0.6534 - val_accuracy: 0.7524 - lr: 1.6000e-07
# Epoch 37/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4243 - accuracy: 0.8132 - val_loss: 0.6490 - val_accuracy: 0.7524 - lr: 3.2000e-08
# Epoch 38/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4213 - accuracy: 0.8235 - val_loss: 0.6537 - val_accuracy: 0.7619 - lr: 3.2000e-08
# Epoch 39/40
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4209 - accuracy: 0.8202 - val_loss: 0.6506 - val_accuracy: 0.7524 - lr: 3.2000e-08
# Epoch 40/40
# 329/329 [==============================] - ETA: 0s - loss: 0.4335 - accuracy: 0.8138
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1e-08.
# 329/329 [==============================] - 12s 36ms/step - loss: 0.4335 - accuracy: 0.8138 - val_loss: 0.6483 - val_accuracy: 0.7524 - lr: 3.2000e-08
# Test Loss: 0.5583240389823914
# Test Accuracy: 0.7770960927009583

# %% [markdown]
# Print the Loss & Accuracy Dictionaries

# %%
print(f"Test Accuracy and Loss Results with Optimizer: {opt.__name__}")
print()
print()
def print_results_dict(Accuracy, Loss):
    print("Print Accuracy Results")
    for key, val in Accuracy.items():
        epochs, lr = key
        print(f"Epochs Number = {epochs}, Learning Rate = {lr}, Accuracy = {val:.3f}")
    print()
    print()
    print("Print Loss Results")
    for key, val in Loss.items():
        epochs, lr = key
        print(f"Epochs Number = {epochs}, Learning Rate = {lr}, Loss = {val:.3f}")


print_results_dict(lr_epoch_test_acc, lr_epoch_test_loss)
# Out:
# Test Accuracy and Loss Results with Optimizer: SGD
#
#
# Print Accuracy Results
# Epochs Number = 10, Learning Rate = 0.001, Accuracy = 0.828
# Epochs Number = 10, Learning Rate = 0.0005, Accuracy = 0.755
# Epochs Number = 10, Learning Rate = 0.0001, Accuracy = 0.757
# Epochs Number = 20, Learning Rate = 0.001, Accuracy = 0.787
# Epochs Number = 20, Learning Rate = 0.0005, Accuracy = 0.816
# Epochs Number = 20, Learning Rate = 0.0001, Accuracy = 0.779
# Epochs Number = 40, Learning Rate = 0.001, Accuracy = 0.818
# Epochs Number = 40, Learning Rate = 0.0005, Accuracy = 0.818
# Epochs Number = 40, Learning Rate = 0.0001, Accuracy = 0.777
#
#
# Print Loss Results
# Epochs Number = 10, Learning Rate = 0.001, Loss = 0.426
# Epochs Number = 10, Learning Rate = 0.0005, Loss = 0.565
# Epochs Number = 10, Learning Rate = 0.0001, Loss = 0.593
# Epochs Number = 20, Learning Rate = 0.001, Loss = 0.481
# Epochs Number = 20, Learning Rate = 0.0005, Loss = 0.467
# Epochs Number = 20, Learning Rate = 0.0001, Loss = 0.588
# Epochs Number = 40, Learning Rate = 0.001, Loss = 0.488
# Epochs Number = 40, Learning Rate = 0.0005, Loss = 0.489
# Epochs Number = 40, Learning Rate = 0.0001, Loss = 0.558
